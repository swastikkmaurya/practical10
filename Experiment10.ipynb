# %% [markdown]
# <a href="https://colab.research.google.com/github/swastikkmaurya/practical10/blob/main/Experiment10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Swastik Maurya
#25070123114
#Study of pandas library

# %%
import pandas as pd

s = pd.Series([1, 3, 5, 6, 8])
print(s)
# Out:
# 0    1
# 1    3
# 2    5
# 3    6
# 4    8
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>

# %%
#create DataFrame
data = {
    "name":["A","B","C"],
    "Marks":[65,90,90]

}
df = pd.DataFrame(data)
print(df)
print(df.shape)
print(df.ndim)
print(df.size)
print(df.columns)
print(df.dtypes)
print(df["name"])
print(df.loc[0,"name"])
print(df.iloc[1])
df["Grade"]=["Fisrt class","Distinction","Second class"]
print(df)
#update of marks
df.loc[0,"Marks"]=88
df.iloc[1,1]=91
print(df)
df1 = df.drop("Grade",axis=1)
print(df1)
print(df)
mean1=df["Marks"].max()
print(mean1)
min1=df["Marks"].min()
print(min1)
max1=df["Marks"].max()
print(max1)
print(df[df["Marks"]>90])
# Out:
#   name  Marks
# 0    A     65
# 1    B     90
# 2    C     90
# (3, 2)
# 2
# 6
# Index(['name', 'Marks'], dtype='object')
# name     object
# Marks     int64
# dtype: object
# 0    A
# 1    B
# 2    C
# Name: name, dtype: object
# A
# name      B
# Marks    90
# Name: 1, dtype: object
#   name  Marks         Grade
# 0    A     65   Fisrt class
# 1    B     90   Distinction
# 2    C     90  Second class
#   name  Marks         Grade
# 0    A     88   Fisrt class
# 1    B     91   Distinction
# 2    C     90  Second class
#   name  Marks
# 0    A     88
# 1    B     91
# 2    C     90
#   name  Marks         Grade
# 0    A     88   Fisrt class
# 1    B     91   Distinction
# 2    C     90  Second class
# 91
# 88
# 91
#   name  Marks        Grade
# 1    B     91  Distinction
